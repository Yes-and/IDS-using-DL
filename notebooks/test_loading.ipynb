# %%
import sys
from pathlib import Path

# Project root is one level up from notebooks/
PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data.xiiotid import load_xiiotid

# %%
df = load_xiiotid(raw_dir=PROJECT_ROOT / "data" / "raw" / "xiiotid")

# %%
df.head()
# Out:
# shape: (5, 83)
# ┌──────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬────────┐
# │ Des_port ┆ Protocol_? ┆ Protocol_i ┆ Protocol_t ┆ … ┆ is_privil ┆ class1    ┆ class2    ┆ class3 │
# │ ---      ┆ ---        ┆ cmp        ┆ cp         ┆   ┆ eged      ┆ ---       ┆ ---       ┆ ---    │
# │ str      ┆ f32        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ str       ┆ str       ┆ str    │
# │          ┆            ┆ f32        ┆ f32        ┆   ┆ f32       ┆           ┆           ┆        │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪════════╡
# │ 80       ┆ 0.0        ┆ 0.0        ┆ 1.0        ┆ … ┆ 0.0       ┆ Scanning_ ┆ Reconnais ┆ Attack │
# │          ┆            ┆            ┆            ┆   ┆           ┆ vulnerabi ┆ sance     ┆        │
# │          ┆            ┆            ┆            ┆   ┆           ┆ lity      ┆           ┆        │
# │ 53       ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ … ┆ 0.0       ┆ Normal    ┆ Normal    ┆ Normal │
# │ 53       ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ … ┆ 0.0       ┆ Normal    ┆ Normal    ┆ Normal │
# │ 1880     ┆ 0.0        ┆ 0.0        ┆ 1.0        ┆ … ┆ 1.0       ┆ Normal    ┆ Normal    ┆ Normal │
# │ 53       ┆ 0.0        ┆ 0.0        ┆ 0.0        ┆ … ┆ 0.0       ┆ Normal    ┆ Normal    ┆ Normal │
# └──────────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴────────┘
